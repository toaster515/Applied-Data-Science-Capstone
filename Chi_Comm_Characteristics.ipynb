# %%
#Libraries
import pandas as pd
import numpy as np
import geopandas as gdp
import requests
from bs4 import BeautifulSoup
import geocoder
from datetime import date
import json
from pandas.io.json import json_normalize
import folium
import geojson
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import re
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
def getsouptable(url, cls):
    response = requests.get(url=url)
    soup = BeautifulSoup(response.content, 'html.parser')
    ctab = soup.find('table', class_=cls)
    cbod = ctab.find('tbody')
    chead = ctab.find('thead')

    rows = chead.find_all('tr')
    heads = []
    for r in rows:
        cols = r.find_all('th')
        cols = [elem.text.strip() for elem in cols]
        heads.append([elem for elem in cols if elem])

    rows = cbod.find_all('tr')
    stuff = []
    for r in rows:
        cols = r.find_all('td')
        cols = [elem.text.strip() for elem in cols]
        stuff.append([elem for elem in cols if elem])
        
    df = pd.DataFrame(stuff)
    df.columns = heads
    return df

# %%
def rawnum(numstr):

    for x in range(0, len(numstr)-1):
        if numstr[x]=="[":
            numstr = numstr[0:x]
            break
            
    for x in range(len(numstr)-1, -1, -1):
        if not numstr[x].isnumeric():
            if numstr[x]==".":
                continue
            else:
                numstr = numstr.replace(numstr[x],"")
    
    return numstr

# %%
url = 'https://www.housingstudies.org/data-portal/browse/?indicator=total-foreclosure-activity&area=chicago-community-areas&property_type=0&view_as=view-table'
cls = 'table table-striped portal-table'
df_forc = getsouptable(url, cls)

# %%
df_forc
# Out:
#          Geography 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015  \
# 0      Albany Park   32   57  149  252  342  375  257  222  123   61   61
# 1   Archer Heights   19   34   43   97  112  128   97   81   45   34   30
# 2    Armour Square    6    5    6    7    8   21   13   25   14    6    2
# 3          Ashburn  246  284  358  527  529  629  514  610  384  263  211
# 4   Auburn Gresham  371  390  520  602  474  515  431  493  336  300  285
# ..             ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 72       West Lawn   75  116  204  377  427  479  349  336  265  136  111
# 73    West Pullman  342  489  556  586  432  388  330  426  260  192  190
# 74      West Ridge   70  138  314  611  823  711  488  455  232  105   79
# 75       West Town  130  146  263  441  584  479  412  319  182   96   75
# 76        Woodlawn  161  213  371  433  318  318  254  227  156  116  100
#
#    2016 2017 2018 2019
# 0    44   47   31   36
# 1    20   22   22   14
# 2     5    5    3   --
# 3   205  235  201  182
# 4   255  282  248  234
# ..  ...  ...  ...  ...
# 72   97  105   83   65
# 73  199  163  163  139
# 74   80   85   68   55
# 75   55   66   59   60
# 76   87   69   89   63
#
# [77 rows x 16 columns]

# %%
keeps = [0,13,14,15]
df_forc = df_forc[df_forc.columns[keeps]]

# %%
df_forc
# Out:
#          Geography 2017 2018 2019
# 0      Albany Park   47   31   36
# 1   Archer Heights   22   22   14
# 2    Armour Square    5    3   --
# 3          Ashburn  235  201  182
# 4   Auburn Gresham  282  248  234
# ..             ...  ...  ...  ...
# 72       West Lawn  105   83   65
# 73    West Pullman  163  163  139
# 74      West Ridge   85   68   55
# 75       West Town   66   59   60
# 76        Woodlawn   69   89   63
#
# [77 rows x 4 columns]

# %%
df_forc = df_forc.replace('--',0)
df_forc
# Out:
#          Geography 2017 2018 2019
# 0      Albany Park   47   31   36
# 1   Archer Heights   22   22   14
# 2    Armour Square    5    3    0
# 3          Ashburn  235  201  182
# 4   Auburn Gresham  282  248  234
# ..             ...  ...  ...  ...
# 72       West Lawn  105   83   65
# 73    West Pullman  163  163  139
# 74      West Ridge   85   68   55
# 75       West Town   66   59   60
# 76        Woodlawn   69   89   63
#
# [77 rows x 4 columns]

# %%
df_forc['2017'] = df_forc['2017'].astype('int64')
df_forc['2018'] = df_forc['2018'].astype('int64')
df_forc['2019'] = df_forc['2019'].astype('int64')
df_forc
# Out:
#          Geography 2017 2018 2019
# 0      Albany Park   47   31   36
# 1   Archer Heights   22   22   14
# 2    Armour Square    5    3    0
# 3          Ashburn  235  201  182
# 4   Auburn Gresham  282  248  234
# ..             ...  ...  ...  ...
# 72       West Lawn  105   83   65
# 73    West Pullman  163  163  139
# 74      West Ridge   85   68   55
# 75       West Town   66   59   60
# 76        Woodlawn   69   89   63
#
# [77 rows x 4 columns]

# %%
sums = [1,2,3]
df_forc['Forclosures'] = df_forc[df_forc.columns[sums]].sum(axis=1)
df_forc
# Out:
#          Geography 2017 2018 2019 Forclosures
# 0      Albany Park   47   31   36         114
# 1   Archer Heights   22   22   14          58
# 2    Armour Square    5    3    0           8
# 3          Ashburn  235  201  182         618
# 4   Auburn Gresham  282  248  234         764
# ..             ...  ...  ...  ...         ...
# 72       West Lawn  105   83   65         253
# 73    West Pullman  163  163  139         465
# 74      West Ridge   85   68   55         208
# 75       West Town   66   59   60         185
# 76        Woodlawn   69   89   63         221
#
# [77 rows x 5 columns]

# %%
url = 'https://www.housingstudies.org/data-portal/browse/?indicator=total-mortgage-activity&area=chicago-community-areas&property_type=0&view_as=view-table'
cls = 'table table-striped portal-table'
df_morg = getsouptable(url, cls)
df_morg
# Out:
#          Geography   2005   2006   2007   2008   2009   2010   2011   2012  \
# 0      Albany Park  2,782  2,618  1,983  1,205    985    903    769  1,025
# 1   Archer Heights    802    638    475    255    190    167    155    219
# 2    Armour Square    397    341    361    306    242    217    166    198
# 3          Ashburn  4,474  3,798  3,054  1,443  1,166    874    782  1,069
# 4   Auburn Gresham  3,202  2,847  2,503  1,261    911    576    501    575
# ..             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 72       West Lawn  2,914  2,269  1,608    823    601    467    454    605
# 73    West Pullman  2,762  2,342  1,891    950    559    381    282    286
# 74      West Ridge  4,377  4,407  3,624  1,914  1,657  1,415  1,243  1,573
# 75       West Town  7,263  7,108  6,698  4,851  4,185  3,643  3,062  4,180
# 76        Woodlawn  1,779  1,792  1,314    639    388    270    238    266
#
#      2013   2014   2015   2016   2017   2018   2019
# 0     936    716    834  1,023    827    697    809
# 1     203    176    185    187    174    151    170
# 2     187    127    142    155    165    167    141
# 3   1,179    868    879  1,053    999    876    910
# 4     632    564    583    708    735    759    821
# ..    ...    ...    ...    ...    ...    ...    ...
# 72    680    476    533    585    562    457    487
# 73    395    300    292    282    336    381    432
# 74  1,481  1,020  1,243  1,438  1,280  1,098  1,176
# 75  4,057  3,284  4,025  4,372  3,517  2,743  3,742
# 76    326    297    313    339    420    394    380
#
# [77 rows x 16 columns]

# %%
keeps = [0,13,14,15]
df_morg = df_morg[df_morg.columns[keeps]]
df_morg
# Out:
#          Geography   2017   2018   2019
# 0      Albany Park    827    697    809
# 1   Archer Heights    174    151    170
# 2    Armour Square    165    167    141
# 3          Ashburn    999    876    910
# 4   Auburn Gresham    735    759    821
# ..             ...    ...    ...    ...
# 72       West Lawn    562    457    487
# 73    West Pullman    336    381    432
# 74      West Ridge  1,280  1,098  1,176
# 75       West Town  3,517  2,743  3,742
# 76        Woodlawn    420    394    380
#
# [77 rows x 4 columns]

# %%
for x in range(0,df_morg.shape[0]):
    for y in range(1, 4):
        df_morg.iat[x,y] = rawnum(df_morg.iat[x,y])
df_morg
# Out:
#          Geography  2017  2018  2019
# 0      Albany Park   827   697   809
# 1   Archer Heights   174   151   170
# 2    Armour Square   165   167   141
# 3          Ashburn   999   876   910
# 4   Auburn Gresham   735   759   821
# ..             ...   ...   ...   ...
# 72       West Lawn   562   457   487
# 73    West Pullman   336   381   432
# 74      West Ridge  1280  1098  1176
# 75       West Town  3517  2743  3742
# 76        Woodlawn   420   394   380
#
# [77 rows x 4 columns]

# %%
df_morg['2017'] = df_morg['2017'].astype('int64')
df_morg['2018'] = df_morg['2018'].astype('int64')
df_morg['2019'] = df_morg['2019'].astype('int64')
df_morg['Mortgages'] = df_morg[df_morg.columns[sums]].sum(axis=1)
df_morg
# Out:
# <ipython-input-14-b6afc6e36f23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morg['2017'] = df_morg['2017'].astype('int64')
# <ipython-input-14-b6afc6e36f23>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morg['2018'] = df_morg['2018'].astype('int64')
# <ipython-input-14-b6afc6e36f23>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morg['2019'] = df_morg['2019'].astype('int64')
# <ipython-input-14-b6afc6e36f23>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_morg['Mortgages'] = df_morg[df_morg.columns[sums]].sum(axis=1)
#          Geography  2017  2018  2019 Mortgages
# 0      Albany Park   827   697   809      2333
# 1   Archer Heights   174   151   170       495
# 2    Armour Square   165   167   141       473
# 3          Ashburn   999   876   910      2785
# 4   Auburn Gresham   735   759   821      2315
# ..             ...   ...   ...   ...       ...
# 72       West Lawn   562   457   487      1506
# 73    West Pullman   336   381   432      1149
# 74      West Ridge  1280  1098  1176      3554
# 75       West Town  3517  2743  3742     10002
# 76        Woodlawn   420   394   380      1194
#
# [77 rows x 5 columns]

# %%
url = 'https://www.housingstudies.org/data-portal/browse/?indicator=poverty-rate&area=chicago-community-areas&view_as=view-table'
cls = 'table table-striped portal-table'
df_pov = getsouptable(url, cls)

# %%
df_pov
# Out:
#          Geography Share of Population that is under the Poverty Level
# 0      Albany Park                                              16.2%
# 1   Archer Heights                                              15.0%
# 2    Armour Square                                              32.8%
# 3          Ashburn                                              12.8%
# 4   Auburn Gresham                                              25.4%
# ..             ...                                                ...
# 72       West Lawn                                              13.6%
# 73    West Pullman                                              22.9%
# 74      West Ridge                                              21.6%
# 75       West Town                                              10.7%
# 76        Woodlawn                                              33.2%
#
# [77 rows x 2 columns]

# %%
for x in range(0,df_pov.shape[0]):
    df_pov.iat[x,1] = float(rawnum(df_pov.iat[x,1]))
    df_pov.iat[x,1] = df_pov.iat[x,1]/100
df_pov
# Out:
#          Geography Share of Population that is under the Poverty Level
# 0      Albany Park                                              0.162
# 1   Archer Heights                                               0.15
# 2    Armour Square                                              0.328
# 3          Ashburn                                              0.128
# 4   Auburn Gresham                                              0.254
# ..             ...                                                ...
# 72       West Lawn                                              0.136
# 73    West Pullman                                              0.229
# 74      West Ridge                                              0.216
# 75       West Town                                              0.107
# 76        Woodlawn                                              0.332
#
# [77 rows x 2 columns]

# %%
url = 'https://www.housingstudies.org/data-portal/browse/?indicator=population-and-age&area=chicago-community-areas&view_as=view-table'
cls = 'table table-striped portal-table'
df_pop = getsouptable(url, cls)
df_pop
# Out:
#          Geography Share of Population Aged under 18  \
# 0      Albany Park                             22.4%
# 1   Archer Heights                             30.0%
# 2    Armour Square                             16.7%
# 3          Ashburn                             26.2%
# 4   Auburn Gresham                             22.8%
# ..             ...                               ...
# 72       West Lawn                             28.5%
# 73    West Pullman                             24.7%
# 74      West Ridge                             26.3%
# 75       West Town                             13.5%
# 76        Woodlawn                             22.4%
#
#    Share of Population Aged 18 to 44 Share of Population Aged 45 to 64  \
# 0                              45.3%                             22.1%
# 1                              38.4%                             18.9%
# 2                              32.2%                             26.1%
# 3                              35.5%                             26.6%
# 4                              32.4%                             26.8%
# ..                               ...                               ...
# 72                             40.0%                             21.0%
# 73                             34.8%                             24.6%
# 74                             36.5%                             23.9%
# 75                             64.8%                             15.7%
# 76                             41.5%                             23.4%
#
#    Share of Population Aged over 65 Total Population
# 0                             10.1%           49,806
# 1                             12.7%           13,726
# 2                             24.9%           13,538
# 3                             11.7%           43,356
# 4                             17.9%           45,909
# ..                              ...              ...
# 72                            10.4%           31,886
# 73                            15.9%           27,028
# 74                            13.3%           78,466
# 75                             5.9%           83,757
# 76                            12.7%           24,844
#
# [77 rows x 6 columns]

# %%
df2 = df_pov.set_index('Geography').join(df_pop.set_index('Geography'))
df2
# Out:
#                   Share of Population that is under the Poverty Level  \
# Geography
# (Albany Park,)                                                 0.162
# (Archer Heights,)                                               0.15
# (Armour Square,)                                               0.328
# (Ashburn,)                                                     0.128
# (Auburn Gresham,)                                              0.254
# ...                                                              ...
# (West Lawn,)                                                   0.136
# (West Pullman,)                                                0.229
# (West Ridge,)                                                  0.216
# (West Town,)                                                   0.107
# (Woodlawn,)                                                    0.332
#
#                   Share of Population Aged under 18  \
# Geography
# (Albany Park,)                                22.4%
# (Archer Heights,)                             30.0%
# (Armour Square,)                              16.7%
# (Ashburn,)                                    26.2%
# (Auburn Gresham,)                             22.8%
# ...                                             ...
# (West Lawn,)                                  28.5%
# (West Pullman,)                               24.7%
# (West Ridge,)                                 26.3%
# (West Town,)                                  13.5%
# (Woodlawn,)                                   22.4%
#
#                   Share of Population Aged 18 to 44  \
# Geography
# (Albany Park,)                                45.3%
# (Archer Heights,)                             38.4%
# (Armour Square,)                              32.2%
# (Ashburn,)                                    35.5%
# (Auburn Gresham,)                             32.4%
# ...                                             ...
# (West Lawn,)                                  40.0%
# (West Pullman,)                               34.8%
# (West Ridge,)                                 36.5%
# (West Town,)                                  64.8%
# (Woodlawn,)                                   41.5%
#
#                   Share of Population Aged 45 to 64  \
# Geography
# (Albany Park,)                                22.1%
# (Archer Heights,)                             18.9%
# (Armour Square,)                              26.1%
# (Ashburn,)                                    26.6%
# (Auburn Gresham,)                             26.8%
# ...                                             ...
# (West Lawn,)                                  21.0%
# (West Pullman,)                               24.6%
# (West Ridge,)                                 23.9%
# (West Town,)                                  15.7%
# (Woodlawn,)                                   23.4%
#
#                   Share of Population Aged over 65 Total Population
# Geography
# (Albany Park,)                               10.1%           49,806
# (Archer Heights,)                            12.7%           13,726
# (Armour Square,)                             24.9%           13,538
# (Ashburn,)                                   11.7%           43,356
# (Auburn Gresham,)                            17.9%           45,909
# ...                                            ...              ...
# (West Lawn,)                                 10.4%           31,886
# (West Pullman,)                              15.9%           27,028
# (West Ridge,)                                13.3%           78,466
# (West Town,)                                  5.9%           83,757
# (Woodlawn,)                                  12.7%           24,844
#
# [77 rows x 6 columns]

# %%
keeps=[0,5]
df2 = df2[df2.columns[keeps]]
df2
# Out:
#                   Share of Population that is under the Poverty Level  \
# Geography
# (Albany Park,)                                                 0.162
# (Archer Heights,)                                               0.15
# (Armour Square,)                                               0.328
# (Ashburn,)                                                     0.128
# (Auburn Gresham,)                                              0.254
# ...                                                              ...
# (West Lawn,)                                                   0.136
# (West Pullman,)                                                0.229
# (West Ridge,)                                                  0.216
# (West Town,)                                                   0.107
# (Woodlawn,)                                                    0.332
#
#                   Total Population
# Geography
# (Albany Park,)              49,806
# (Archer Heights,)           13,726
# (Armour Square,)            13,538
# (Ashburn,)                  43,356
# (Auburn Gresham,)           45,909
# ...                            ...
# (West Lawn,)                31,886
# (West Pullman,)             27,028
# (West Ridge,)               78,466
# (West Town,)                83,757
# (Woodlawn,)                 24,844
#
# [77 rows x 2 columns]

# %%
for x in range(0,df2.shape[0]):
    df2.iat[x,1] = int(rawnum(df2.iat[x,1]))

# %%
df2['Poverty'] = df2[df2.columns[0]] * df2[df2.columns[1]]
# Out:
# <ipython-input-22-23522e40ab8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Poverty'] = df2[df2.columns[0]] * df2[df2.columns[1]]

# %%
df2 = df2[df2.columns[list([0,1,2])]]
df2
# Out:
#                   Share of Population that is under the Poverty Level  \
# Geography
# (Albany Park,)                                                 0.162
# (Archer Heights,)                                               0.15
# (Armour Square,)                                               0.328
# (Ashburn,)                                                     0.128
# (Auburn Gresham,)                                              0.254
# ...                                                              ...
# (West Lawn,)                                                   0.136
# (West Pullman,)                                                0.229
# (West Ridge,)                                                  0.216
# (West Town,)                                                   0.107
# (Woodlawn,)                                                    0.332
#
#                   Total Population    Poverty
# Geography
# (Albany Park,)               49806   8068.572
# (Archer Heights,)            13726     2058.9
# (Armour Square,)             13538   4440.464
# (Ashburn,)                   43356   5549.568
# (Auburn Gresham,)            45909  11660.886
# ...                            ...        ...
# (West Lawn,)                 31886   4336.496
# (West Pullman,)              27028   6189.412
# (West Ridge,)                78466  16948.656
# (West Town,)                 83757   8961.999
# (Woodlawn,)                  24844   8248.208
#
# [77 rows x 3 columns]

# %%
df2 = df2.join(df_forc.set_index('Geography'))

# %%
df2 = df2[df2.columns[list([1,2,6])]]
df2
# Out:
#                   Total Population    Poverty Forclosures
# Geography
# (Albany Park,)               49806   8068.572         114
# (Archer Heights,)            13726     2058.9          58
# (Armour Square,)             13538   4440.464           8
# (Ashburn,)                   43356   5549.568         618
# (Auburn Gresham,)            45909  11660.886         764
# ...                            ...        ...         ...
# (West Lawn,)                 31886   4336.496         253
# (West Pullman,)              27028   6189.412         465
# (West Ridge,)                78466  16948.656         208
# (West Town,)                 83757   8961.999         185
# (Woodlawn,)                  24844   8248.208         221
#
# [77 rows x 3 columns]

# %%
df2 = df2.join(df_morg.set_index('Geography'))

# %%
df2 = df2[df2.columns[list([0,1,2,6])]]
df2
# Out:
#                   Total Population    Poverty Forclosures Mortgages
# Geography
# (Albany Park,)               49806   8068.572         114      2333
# (Archer Heights,)            13726     2058.9          58       495
# (Armour Square,)             13538   4440.464           8       473
# (Ashburn,)                   43356   5549.568         618      2785
# (Auburn Gresham,)            45909  11660.886         764      2315
# ...                            ...        ...         ...       ...
# (West Lawn,)                 31886   4336.496         253      1506
# (West Pullman,)              27028   6189.412         465      1149
# (West Ridge,)                78466  16948.656         208      3554
# (West Town,)                 83757   8961.999         185     10002
# (Woodlawn,)                  24844   8248.208         221      1194
#
# [77 rows x 4 columns]

# %%
df2 = df2.reset_index()
df2.columns.values[0]='Geography'
df2
# Out:
#             Geography Total Population    Poverty Forclosures Mortgages
# 0      (Albany Park,)            49806   8068.572         114      2333
# 1   (Archer Heights,)            13726     2058.9          58       495
# 2    (Armour Square,)            13538   4440.464           8       473
# 3          (Ashburn,)            43356   5549.568         618      2785
# 4   (Auburn Gresham,)            45909  11660.886         764      2315
# ..                ...              ...        ...         ...       ...
# 72       (West Lawn,)            31886   4336.496         253      1506
# 73    (West Pullman,)            27028   6189.412         465      1149
# 74      (West Ridge,)            78466  16948.656         208      3554
# 75       (West Town,)            83757   8961.999         185     10002
# 76        (Woodlawn,)            24844   8248.208         221      1194
#
# [77 rows x 5 columns]

# %%
df2 = df2[df2.columns[list([0,1,2,3,4])]]
df2
# Out:
#             Geography Total Population    Poverty Forclosures Mortgages
# 0      (Albany Park,)            49806   8068.572         114      2333
# 1   (Archer Heights,)            13726     2058.9          58       495
# 2    (Armour Square,)            13538   4440.464           8       473
# 3          (Ashburn,)            43356   5549.568         618      2785
# 4   (Auburn Gresham,)            45909  11660.886         764      2315
# ..                ...              ...        ...         ...       ...
# 72       (West Lawn,)            31886   4336.496         253      1506
# 73    (West Pullman,)            27028   6189.412         465      1149
# 74      (West Ridge,)            78466  16948.656         208      3554
# 75       (West Town,)            83757   8961.999         185     10002
# 76        (Woodlawn,)            24844   8248.208         221      1194
#
# [77 rows x 5 columns]

# %%
for x in range(0,df2.shape[0]):
    df2.iat[x,0]=df2.iat[x,0][0]

# %%
df2
# Out:
#          Geography Total Population    Poverty Forclosures Mortgages
# 0      Albany Park            49806   8068.572         114      2333
# 1   Archer Heights            13726     2058.9          58       495
# 2    Armour Square            13538   4440.464           8       473
# 3          Ashburn            43356   5549.568         618      2785
# 4   Auburn Gresham            45909  11660.886         764      2315
# ..             ...              ...        ...         ...       ...
# 72       West Lawn            31886   4336.496         253      1506
# 73    West Pullman            27028   6189.412         465      1149
# 74      West Ridge            78466  16948.656         208      3554
# 75       West Town            83757   8961.999         185     10002
# 76        Woodlawn            24844   8248.208         221      1194
#
# [77 rows x 5 columns]

# %%
#df2.to_csv('Chi_Comm_Character.csv', index=False)
